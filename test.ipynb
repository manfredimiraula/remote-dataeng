# %%
import pandas as pd
import numpy as np
from tableschema import infer
from modules.utils.utils import read_json , initialize_tables_in_db, load_to_postgres, build_connection_engine
from pathlib import Path

p = Path(".")

config = read_json(p / "modules"/"config.json")
table_schema = 'remote'

# %% [markdown]
# # 1 - Load raw data

# %%
sheets = pd.ExcelFile('Data Analyst Assignment.xlsx')

# %%
# here we load the data from the sheets into pandas DF
# this will generate a dictionary that maps all the sheets
dct = pd.read_excel(sheets, sheet_name=None)

# %% [markdown]
# # 2 - Load raw data in staging tables in Postgres DB
#
# Here I want to
# 1. Load all the raw data into postgres into the public.table schema. This will be our raw/stagin section
# 2. Once all the data is loaded, I can perform the EDA and evaluate how to normalize the table to account for missing data, bad data

# %%
for key in dct:
    print(len(dct[key]))
# Out:
# 99
# 18484
# 569
# 11
# 3
# 39409
# 60855

# %%
initialize_tables_in_db(config, dct, table_schema)
# Out:
# dimaccounts
# False
# Initializing table
# dimcustomer
# False
# Initializing table
# dimproduct
# False
# Initializing table
# dimsalesterritory
# False
# Initializing table
# dimscenario
# False
# Initializing table
# factfinance
# False
# Initializing table
# factresellersales
# False
# Initializing table

# %%
load_to_postgres(config, dct, table_schema)
# Out:
# <class 'str'>
# dimaccounts
# Inserted 99 rows in remote.dimaccounts
# <class 'str'>
# dimcustomer
# Inserted 18484 rows in remote.dimcustomer
# <class 'str'>
# dimproduct
# Inserted 569 rows in remote.dimproduct
# <class 'str'>
# dimsalesterritory
# Inserted 11 rows in remote.dimsalesterritory
# <class 'str'>
# dimscenario
# Inserted 3 rows in remote.dimscenario
# <class 'str'>
# factfinance
# Inserted 39409 rows in remote.factfinance
# <class 'str'>
# factresellersales
# Inserted 60855 rows in remote.factresellersales

# %% [markdown]
# # 3 - Perform EDA on the raw data
#
# ### EDA on DimAccounts

# %%
p = Path(".")

config = read_json(p / "modules"/"config.json")
conn_s = build_connection_engine(config, 's')

# %%
df = pd.read_sql_query(f"select * from {table_schema}.dimcustomer ",con=conn_s)

# %% [markdown]
# # issues
#
# - dimaccounts -> potentially faulty custommembers
# - dimcustomer -> birthdate, datefirstpurchase, phone number (strip)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerkey           18484 non-null  float64
#  1   geographykey          18484 non-null  float64
#  2   customeralternatekey  18484 non-null  object
#  3   title                 101 non-null    object
#  4   firstname             18484 non-null  object
#  5   middlename            10654 non-null  object
#  6   lastname              18484 non-null  object
#  7   namestyle             18484 non-null  float64
#  8   birthdate             18484 non-null  object
#  9   maritalstatus         18484 non-null  object
#  10  suffix                3 non-null      object
#  11  gender                18484 non-null  object
#  12  emailaddress          18484 non-null  object
#  13  yearlyincome          18484 non-null  float64
#  14  totalchildren         18484 non-null  float64
#  15  numberchildrenathome  18484 non-null  float64
#  16  englisheducation      18484 non-null  object
#  17  spanisheducation      18484 non-null  object
#  18  frencheducation       18484 non-null  object
#  19  englishoccupation     18484 non-null  object
#  20  spanishoccupation     18484 non-null  object
#  21  frenchoccupation      18484 non-null  object
#  22  houseownerflag        18484 non-null  float64
#  23  numbercarsowned       18484 non-null  float64
#  24  addressline1          18484 non-null  object
#  25  addressline2          312 non-null    object
#  26  phone                 18484 non-null  object
#  27  datefirstpurchase     18484 non-null  object
#  28  commutedistance       18484 non-null  object
# dtypes: float64(8), object(21)
# memory usage: 4.1+ MB

# %%
df
# Out:
#        customerkey  geographykey customeralternatekey title  firstname  \
# 0          11000.0          26.0           AW00011000  None        Jon
# 1          11001.0          37.0           AW00011001  None     Eugene
# 2          11002.0          31.0           AW00011002  None      Ruben
# 3          11003.0          11.0           AW00011003  None    Christy
# 4          11004.0          19.0           AW00011004  None  Elizabeth
# ...            ...           ...                  ...   ...        ...
# 18479      29479.0         209.0           AW00029479  None      Tommy
# 18480      29480.0         248.0           AW00029480  None       Nina
# 18481      29481.0         120.0           AW00029481  None       Ivan
# 18482      29482.0         179.0           AW00029482  None    Clayton
# 18483      29483.0         217.0           AW00029483  None      Jésus
#
#       middlename lastname  namestyle            birthdate maritalstatus  ...  \
# 0              V     Yang        0.0  1971-06-10 00:00:00             M  ...
# 1              L    Huang        0.0  1976-10-05 00:00:00             S  ...
# 2           None   Torres        0.0  1971-09-02 00:00:00             M  ...
# 3           None      Zhu        0.0             14/08/73             S  ...
# 4           None  Johnson        0.0  1979-05-08 00:00:00             S  ...
# ...          ...      ...        ...                  ...           ...  ...
# 18479          L     Tang        0.0             30/06/69             M  ...
# 18480          W     Raji        0.0  1977-06-05 00:00:00             S  ...
# 18481       None     Suri        0.0  1965-04-07 00:00:00             S  ...
# 18482       None    Zhang        0.0  1964-01-09 00:00:00             M  ...
# 18483          L  Navarro        0.0  1965-06-06 00:00:00             M  ...
#
#       englishoccupation spanishoccupation frenchoccupation  houseownerflag  \
# 0          Professional       Profesional            Cadre             1.0
# 1          Professional       Profesional            Cadre             0.0
# 2          Professional       Profesional            Cadre             1.0
# 3          Professional       Profesional            Cadre             0.0
# 4          Professional       Profesional            Cadre             1.0
# ...                 ...               ...              ...             ...
# 18479          Clerical    Administrativo          Employé             1.0
# 18480          Clerical    Administrativo          Employé             1.0
# 18481          Clerical    Administrativo          Employé             0.0
# 18482          Clerical    Administrativo          Employé             1.0
# 18483          Clerical    Administrativo          Employé             1.0
#
#        numbercarsowned               addressline1 addressline2  \
# 0                  0.0            3761 N. 14th St         None
# 1                  1.0                 2243 W St.         None
# 2                  1.0           5844 Linden Land         None
# 3                  1.0           1825 Village Pl.         None
# 4                  4.0        7553 Harness Circle         None
# ...                ...                        ...          ...
# 18479              0.0          111, rue Maillard         None
# 18480              0.0          9 Katherine Drive         None
# 18481              0.0                Knaackstr 4         None
# 18482              0.0     1080, quai de Grenelle         None
# 18483              0.0  244, rue de la Centenaire         None
#
#                      phone    datefirstpurchase commutedistance
# 0      1 (11) 500 555-0162             19/01/11       1-2 Miles
# 1      1 (11) 500 555-0110             15/01/11       0-1 Miles
# 2      1 (11) 500 555-0184  2011-07-01 00:00:00       2-5 Miles
# 3      1 (11) 500 555-0162             29/12/10      5-10 Miles
# 4      1 (11) 500 555-0131             23/01/11       1-2 Miles
# ...                    ...                  ...             ...
# 18479  1 (11) 500 555-0136  2012-04-09 00:00:00       0-1 Miles
# 18480  1 (11) 500 555-0146             17/07/13       0-1 Miles
# 18481  1 (11) 500 555-0144             13/08/11       0-1 Miles
# 18482  1 (11) 500 555-0137             18/09/12       0-1 Miles
# 18483  1 (11) 500 555-0141  2012-09-09 00:00:00       0-1 Miles
#
# [18484 rows x 29 columns]
